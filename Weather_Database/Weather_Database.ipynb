# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description ": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tavda
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | kathmandu
# Processing Record 7 of Set 1 | barcelos
# Processing Record 8 of Set 1 | safranbolu
# Processing Record 9 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 1 | devils lake
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | katubao
# Processing Record 15 of Set 1 | milkovo
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | aklavik
# Processing Record 18 of Set 1 | hinton
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | lorengau
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | lasa
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | cabatuan
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | kaputa
# Processing Record 33 of Set 1 | oranjemund
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | vostok
# Processing Record 45 of Set 1 | college
# Processing Record 46 of Set 1 | northam
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | mogadishu
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | cehal
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | gore
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 2 | hami
# Processing Record 13 of Set 2 | half moon bay
# Processing Record 14 of Set 2 | pangody
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | repatriacion
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | lagoa
# Processing Record 22 of Set 2 | tokur
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | ken caryl
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | kargapolye
# City not found. Skipping...
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | los llanos de aridane
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | tongliao
# Processing Record 33 of Set 2 | manaure
# Processing Record 34 of Set 2 | presidencia roque saenz pena
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | makakilo city
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | boulsa
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 2 | moron
# Processing Record 42 of Set 2 | gat
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | karatuzskoye
# Processing Record 46 of Set 2 | ust-tsilma
# Processing Record 47 of Set 2 | bathsheba
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | buraydah
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | muros
# Processing Record 3 of Set 3 | saint-francois
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | ouargaye
# Processing Record 6 of Set 3 | mecca
# Processing Record 7 of Set 3 | uvira
# Processing Record 8 of Set 3 | alyangula
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | tezu
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | simao
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | ulaanbaatar
# Processing Record 16 of Set 3 | karangampel
# Processing Record 17 of Set 3 | derzhavinsk
# Processing Record 18 of Set 3 | beni
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | hidrolandia
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | faya
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | san isidro
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | zakamensk
# Processing Record 30 of Set 3 | havelock
# Processing Record 31 of Set 3 | lowestoft
# Processing Record 32 of Set 3 | poum
# Processing Record 33 of Set 3 | butler
# Processing Record 34 of Set 3 | feira de santana
# Processing Record 35 of Set 3 | sao mateus
# Processing Record 36 of Set 3 | blairmore
# Processing Record 37 of Set 3 | ormara
# Processing Record 38 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | kokopo
# Processing Record 42 of Set 3 | mandalgovi
# Processing Record 43 of Set 3 | himora
# City not found. Skipping...
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | nome
# Processing Record 46 of Set 3 | sabha
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | itarema
# Processing Record 1 of Set 4 | luanda
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | surab
# Processing Record 5 of Set 4 | nokaneng
# Processing Record 6 of Set 4 | kiruna
# Processing Record 7 of Set 4 | fukue
# Processing Record 8 of Set 4 | mucuri
# Processing Record 9 of Set 4 | okhotsk
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | la cruz
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | omsukchan
# Processing Record 18 of Set 4 | komsomolskiy
# Processing Record 19 of Set 4 | axim
# Processing Record 20 of Set 4 | marawi
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | camocim
# Processing Record 23 of Set 4 | itoman
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | seoul
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | biak
# Processing Record 29 of Set 4 | mawlaik
# Processing Record 30 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | linguere
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | sinnamary
# Processing Record 36 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 4 | turukhansk
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | saint-augustin
# Processing Record 41 of Set 4 | rosarito
# Processing Record 42 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 4 | cap malheureux
# Processing Record 45 of Set 4 | eyl
# Processing Record 46 of Set 4 | arcata
# Processing Record 47 of Set 4 | pokosnoye
# Processing Record 48 of Set 4 | makushino
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | santiago
# Processing Record 2 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 3 of Set 5 | lodja
# Processing Record 4 of Set 5 | ulladulla
# Processing Record 5 of Set 5 | ixtapa
# Processing Record 6 of Set 5 | sambava
# Processing Record 7 of Set 5 | astoria
# Processing Record 8 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 5 | ballina
# Processing Record 10 of Set 5 | chimbote
# Processing Record 11 of Set 5 | arroio grande
# Processing Record 12 of Set 5 | hambantota
# Processing Record 13 of Set 5 | mount isa
# Processing Record 14 of Set 5 | quime
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | greece
# Processing Record 17 of Set 5 | karratha
# Processing Record 18 of Set 5 | lavrentiya
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | vilyuysk
# Processing Record 21 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 5 | palmer
# Processing Record 24 of Set 5 | beidao
# Processing Record 25 of Set 5 | chimoio
# Processing Record 26 of Set 5 | mackay
# Processing Record 27 of Set 5 | sungai besar
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | oktyabrskiy
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | wawa
# Processing Record 35 of Set 5 | talcahuano
# Processing Record 36 of Set 5 | lamar
# Processing Record 37 of Set 5 | slobozia
# Processing Record 38 of Set 5 | anloga
# Processing Record 39 of Set 5 | raudeberg
# Processing Record 40 of Set 5 | strelitsa
# Processing Record 41 of Set 5 | guadalupe victoria
# Processing Record 42 of Set 5 | rosetta
# Processing Record 43 of Set 5 | salalah
# Processing Record 44 of Set 5 | solnechnyy
# Processing Record 45 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 5 | krizevci
# Processing Record 47 of Set 5 | phonhong
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | bentiu
# Processing Record 1 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 2 of Set 6 | pedernales
# Processing Record 3 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | pandan
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | dejen
# Processing Record 8 of Set 6 | erzin
# Processing Record 9 of Set 6 | garango
# Processing Record 10 of Set 6 | port augusta
# Processing Record 11 of Set 6 | turkistan
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | vanavara
# Processing Record 14 of Set 6 | anzio
# Processing Record 15 of Set 6 | takehara
# Processing Record 16 of Set 6 | uelzen
# Processing Record 17 of Set 6 | batagay
# Processing Record 18 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | asosa
# Processing Record 21 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 6 | victoria
# Processing Record 23 of Set 6 | chumikan
# Processing Record 24 of Set 6 | nhulunbuy
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | colomi
# Processing Record 28 of Set 6 | xacmaz
# Processing Record 29 of Set 6 | estelle
# Processing Record 30 of Set 6 | mizan teferi
# Processing Record 31 of Set 6 | am timan
# Processing Record 32 of Set 6 | chifeng
# Processing Record 33 of Set 6 | santa cruz de tenerife
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | escanaba
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | nalut
# Processing Record 38 of Set 6 | marsa matruh
# Processing Record 39 of Set 6 | praia da vitoria
# Processing Record 40 of Set 6 | tadine
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | alta floresta
# Processing Record 43 of Set 6 | bilibino
# Processing Record 44 of Set 6 | vila velha
# Processing Record 45 of Set 6 | caloundra
# Processing Record 46 of Set 6 | mahibadhoo
# Processing Record 47 of Set 6 | bardiyah
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | samarkand
# Processing Record 50 of Set 6 | ban nahin
# Processing Record 1 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 7 | panorama
# Processing Record 3 of Set 7 | valdemarpils
# Processing Record 4 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 7 | leningradskiy
# Processing Record 6 of Set 7 | balao
# Processing Record 7 of Set 7 | lazaro cardenas
# Processing Record 8 of Set 7 | maumere
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | saskylakh
# Processing Record 11 of Set 7 | port-de-bouc
# Processing Record 12 of Set 7 | bulgan
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | lompoc
# Processing Record 15 of Set 7 | mersing
# Processing Record 16 of Set 7 | selma
# Processing Record 17 of Set 7 | severo-kurilsk
# Processing Record 18 of Set 7 | quelimane
# Processing Record 19 of Set 7 | poretskoye
# Processing Record 20 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 7 | bajil
# Processing Record 22 of Set 7 | san carlos de bariloche
# Processing Record 23 of Set 7 | birjand
# Processing Record 24 of Set 7 | portland
# Processing Record 25 of Set 7 | pandharpur
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | pavlovka
# Processing Record 28 of Set 7 | yining
# Processing Record 29 of Set 7 | kailua
# Processing Record 30 of Set 7 | hay river
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | baghdad
# Processing Record 33 of Set 7 | chapais
# Processing Record 34 of Set 7 | saldanha
# Processing Record 35 of Set 7 | yerbogachen
# Processing Record 36 of Set 7 | port hardy
# Processing Record 37 of Set 7 | basoko
# Processing Record 38 of Set 7 | jumla
# Processing Record 39 of Set 7 | balkanabat
# Processing Record 40 of Set 7 | iranshahr
# Processing Record 41 of Set 7 | maningrida
# Processing Record 42 of Set 7 | zyryanovsk
# Processing Record 43 of Set 7 | haimen
# Processing Record 44 of Set 7 | pingxiang
# Processing Record 45 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 7 | bethanien
# Processing Record 47 of Set 7 | yambio
# Processing Record 48 of Set 7 | shelkovskaya
# Processing Record 49 of Set 7 | mezhdurechensk
# Processing Record 50 of Set 7 | dongfeng
# Processing Record 1 of Set 8 | muli
# Processing Record 2 of Set 8 | floro
# Processing Record 3 of Set 8 | maceio
# Processing Record 4 of Set 8 | goundam
# Processing Record 5 of Set 8 | angoche
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | pasighat
# Processing Record 8 of Set 8 | emerald
# Processing Record 9 of Set 8 | kintampo
# Processing Record 10 of Set 8 | maarianhamina
# Processing Record 11 of Set 8 | tunghsiao
# City not found. Skipping...
# Processing Record 12 of Set 8 | tiarei
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | mehamn
# Processing Record 15 of Set 8 | port hedland
# Processing Record 16 of Set 8 | putina
# Processing Record 17 of Set 8 | amethi
# Processing Record 18 of Set 8 | nerchinskiy zavod
# Processing Record 19 of Set 8 | wanaka
# Processing Record 20 of Set 8 | belmonte
# Processing Record 21 of Set 8 | bambous virieux
# Processing Record 22 of Set 8 | amuntai
# Processing Record 23 of Set 8 | tilichiki
# Processing Record 24 of Set 8 | kijang
# Processing Record 25 of Set 8 | bagan
# Processing Record 26 of Set 8 | ugoofaaru
# Processing Record 27 of Set 8 | bahia blanca
# Processing Record 28 of Set 8 | boshnyakovo
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | mugur-aksy
# Processing Record 32 of Set 8 | kisangani
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | taraz
# Processing Record 35 of Set 8 | udachnyy
# Processing Record 36 of Set 8 | havre-saint-pierre
# Processing Record 37 of Set 8 | ewa beach
# Processing Record 38 of Set 8 | zatoka
# Processing Record 39 of Set 8 | kenai
# Processing Record 40 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 8 | natal
# Processing Record 42 of Set 8 | mileai
# City not found. Skipping...
# Processing Record 43 of Set 8 | makokou
# Processing Record 44 of Set 8 | chipinge
# Processing Record 45 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 8 | yumen
# Processing Record 47 of Set 8 | padang
# Processing Record 48 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 8 | tera
# Processing Record 50 of Set 8 | torbay
# Processing Record 1 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 9 | yar-sale
# Processing Record 3 of Set 9 | atasu
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | trelew
# Processing Record 6 of Set 9 | sapa
# Processing Record 7 of Set 9 | pemba
# Processing Record 8 of Set 9 | henties bay
# Processing Record 9 of Set 9 | milici
# Processing Record 10 of Set 9 | ifanadiana
# Processing Record 11 of Set 9 | segezha
# Processing Record 12 of Set 9 | usinsk
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 9 | svetlogorsk
# Processing Record 16 of Set 9 | viedma
# Processing Record 17 of Set 9 | cape elizabeth
# City not found. Skipping...
# Processing Record 18 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | nipawin
# Processing Record 20 of Set 9 | nijar
# Processing Record 21 of Set 9 | kiunga
# Processing Record 22 of Set 9 | dorado
# Processing Record 23 of Set 9 | mar del plata
# Processing Record 24 of Set 9 | srednekolymsk
# Processing Record 25 of Set 9 | ahuimanu
# Processing Record 26 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 27 of Set 9 | faanui
# Processing Record 28 of Set 9 | gidam
# Processing Record 29 of Set 9 | plonsk
# Processing Record 30 of Set 9 | koulikoro
# Processing Record 31 of Set 9 | cabedelo
# Processing Record 32 of Set 9 | pimentel
# Processing Record 33 of Set 9 | kiri buru
# Processing Record 34 of Set 9 | kungurtug
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | buzmeyin
# Processing Record 39 of Set 9 | rabo de peixe
# Processing Record 40 of Set 9 | porto novo
# Processing Record 41 of Set 9 | tevaitoa
# Processing Record 42 of Set 9 | walvis bay
# Processing Record 43 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 9 | vestmannaeyjar
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | arica
# Processing Record 47 of Set 9 | husavik
# Processing Record 48 of Set 9 | morro bay
# Processing Record 49 of Set 9 | bandiagara
# Processing Record 50 of Set 9 | jasper
# Processing Record 1 of Set 10 | nizwa
# Processing Record 2 of Set 10 | karonga
# Processing Record 3 of Set 10 | gravdal
# Processing Record 4 of Set 10 | herat
# Processing Record 5 of Set 10 | sarangani
# Processing Record 6 of Set 10 | walla walla
# Processing Record 7 of Set 10 | saint austell
# Processing Record 8 of Set 10 | beloha
# Processing Record 9 of Set 10 | yelan
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | hofn
# Processing Record 12 of Set 10 | del rio
# Processing Record 13 of Set 10 | morehead
# Processing Record 14 of Set 10 | brae
# Processing Record 15 of Set 10 | kedrovyy
# Processing Record 16 of Set 10 | baijiantan
# Processing Record 17 of Set 10 | sibu
# Processing Record 18 of Set 10 | takayama
# Processing Record 19 of Set 10 | maniitsoq
# Processing Record 20 of Set 10 | pangai
# Processing Record 21 of Set 10 | mastic beach
# Processing Record 22 of Set 10 | batken
# Processing Record 23 of Set 10 | bloemfontein
# Processing Record 24 of Set 10 | akyab
# Processing Record 25 of Set 10 | oudtshoorn
# Processing Record 26 of Set 10 | melilla
# Processing Record 27 of Set 10 | gori
# Processing Record 28 of Set 10 | kavieng
# Processing Record 29 of Set 10 | rosetown
# Processing Record 30 of Set 10 | honiara
# Processing Record 31 of Set 10 | altamira
# Processing Record 32 of Set 10 | comodoro rivadavia
# Processing Record 33 of Set 10 | nantucket
# Processing Record 34 of Set 10 | wellington
# Processing Record 35 of Set 10 | porkhov
# Processing Record 36 of Set 10 | horsham
# Processing Record 37 of Set 10 | cao bang
# Processing Record 38 of Set 10 | orumiyeh
# Processing Record 39 of Set 10 | sicuani
# Processing Record 40 of Set 10 | umm kaddadah
# Processing Record 41 of Set 10 | almeirim
# Processing Record 42 of Set 10 | carhuaz
# Processing Record 43 of Set 10 | garissa
# Processing Record 44 of Set 10 | sept-iles
# Processing Record 45 of Set 10 | lisakovsk
# Processing Record 46 of Set 10 | road town
# Processing Record 47 of Set 10 | abu zabad
# Processing Record 48 of Set 10 | noumea
# Processing Record 49 of Set 10 | kondinskoye
# Processing Record 50 of Set 10 | daru
# Processing Record 1 of Set 11 | geilo
# Processing Record 2 of Set 11 | gornopravdinsk
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | valparaiso
# Processing Record 5 of Set 11 | kuah
# Processing Record 6 of Set 11 | fortuna
# Processing Record 7 of Set 11 | kologriv
# Processing Record 8 of Set 11 | sao jose da coroa grande
# Processing Record 9 of Set 11 | vincennes
# Processing Record 10 of Set 11 | alugan
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | san jose de ocoa
# Processing Record 15 of Set 11 | husum
# Processing Record 16 of Set 11 | aksarka
# Processing Record 17 of Set 11 | progreso
# Processing Record 18 of Set 11 | fairbanks
# Processing Record 19 of Set 11 | kurilsk
# Processing Record 20 of Set 11 | nioro
# Processing Record 21 of Set 11 | balaka
# Processing Record 22 of Set 11 | mundi
# Processing Record 23 of Set 11 | sumbe
# Processing Record 24 of Set 11 | tignere
# Processing Record 25 of Set 11 | ishim
# Processing Record 26 of Set 11 | richards bay
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | rawson
# Processing Record 29 of Set 11 | barroualie
# City not found. Skipping...
# Processing Record 30 of Set 11 | tarko-sale
# Processing Record 31 of Set 11 | glenluce
# Processing Record 32 of Set 11 | mombetsu
# Processing Record 33 of Set 11 | ayat
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | mango
# Processing Record 36 of Set 11 | tomball
# Processing Record 37 of Set 11 | sayat
# Processing Record 38 of Set 11 | mildura
# Processing Record 39 of Set 11 | galesburg
# Processing Record 40 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 41 of Set 11 | bintulu
# Processing Record 42 of Set 11 | doka
# Processing Record 43 of Set 11 | timizart
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 11 | novaya igirma
# Processing Record 47 of Set 11 | dauriya
# Processing Record 48 of Set 11 | conde
# Processing Record 49 of Set 11 | nisia floresta
# Processing Record 50 of Set 11 | cabra
# Processing Record 1 of Set 12 | garden city
# Processing Record 2 of Set 12 | hirara
# Processing Record 3 of Set 12 | smithers
# Processing Record 4 of Set 12 | bell ville
# Processing Record 5 of Set 12 | mao
# Processing Record 6 of Set 12 | ossora
# Processing Record 7 of Set 12 | vardo
# Processing Record 8 of Set 12 | palembang
# Processing Record 9 of Set 12 | kidal
# Processing Record 10 of Set 12 | varna
# Processing Record 11 of Set 12 | nara
# Processing Record 12 of Set 12 | pinawa
# Processing Record 13 of Set 12 | maues
# Processing Record 14 of Set 12 | senno
# Processing Record 15 of Set 12 | xiaoweizhai
# Processing Record 16 of Set 12 | nagato
# Processing Record 17 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 12 | neiafu
# Processing Record 19 of Set 12 | alanya
# Processing Record 20 of Set 12 | santa isabel do rio negro
# Processing Record 21 of Set 12 | cariamanga
# Processing Record 22 of Set 12 | portpatrick
# City not found. Skipping...
# Processing Record 23 of Set 12 | topolobampo
# Processing Record 24 of Set 12 | zhezkazgan
# Processing Record 25 of Set 12 | calabar
# Processing Record 26 of Set 12 | tual
# Processing Record 27 of Set 12 | mareeba
# Processing Record 28 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 29 of Set 12 | port moresby
# Processing Record 30 of Set 12 | holme
# Processing Record 31 of Set 12 | ostrovnoy
# Processing Record 32 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 33 of Set 12 | waw
# Processing Record 34 of Set 12 | zhuhai
# Processing Record 35 of Set 12 | kamenka
# Processing Record 36 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 12 | mufumbwe
# Processing Record 38 of Set 12 | dodge city
# Processing Record 39 of Set 12 | saint anthony
# Processing Record 40 of Set 12 | svecha
# Processing Record 41 of Set 12 | stornoway
# Processing Record 42 of Set 12 | palu
# Processing Record 43 of Set 12 | aden
# Processing Record 44 of Set 12 | narsaq
# Processing Record 45 of Set 12 | carora
# Processing Record 46 of Set 12 | nelson bay
# Processing Record 47 of Set 12 | boddam
# Processing Record 48 of Set 12 | dryden
# Processing Record 49 of Set 12 | carauari
# Processing Record 50 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 1 of Set 13 | grindavik
# Processing Record 2 of Set 13 | norrtalje
# Processing Record 3 of Set 13 | numan
# Processing Record 4 of Set 13 | deputatskiy
# Processing Record 5 of Set 13 | guadalupe
# Processing Record 6 of Set 13 | kupang
# Processing Record 7 of Set 13 | saint-georges
# Processing Record 8 of Set 13 | namatanai
# Processing Record 9 of Set 13 | juba
# Processing Record 10 of Set 13 | vung tau
# Processing Record 11 of Set 13 | gondanglegi
# Processing Record 12 of Set 13 | avera
# Processing Record 13 of Set 13 | oranjestad
# Processing Record 14 of Set 13 | golden
# Processing Record 15 of Set 13 | sungairaya
# Processing Record 16 of Set 13 | cranbrook
# Processing Record 17 of Set 13 | laguna
# Processing Record 18 of Set 13 | bataipora
# Processing Record 19 of Set 13 | polunochnoye
# Processing Record 20 of Set 13 | malegaon
# Processing Record 21 of Set 13 | pecos
# Processing Record 22 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 13 | arbagar
# Processing Record 24 of Set 13 | vallenar
# Processing Record 25 of Set 13 | byron bay
# Processing Record 26 of Set 13 | charters towers
# Processing Record 27 of Set 13 | samarai
# Processing Record 28 of Set 13 | nikki
# Processing Record 29 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 13 | verkhnevilyuysk
# Processing Record 31 of Set 13 | yarmouth
# Processing Record 32 of Set 13 | alice springs
# Processing Record 33 of Set 13 | dubbo
# Processing Record 34 of Set 13 | chute-aux-outardes
# Processing Record 35 of Set 13 | vila franca do campo
# Processing Record 36 of Set 13 | zamora
# Processing Record 37 of Set 13 | san francisco
# Processing Record 38 of Set 13 | oga
# Processing Record 39 of Set 13 | lakeway
# Processing Record 40 of Set 13 | lucea
# Processing Record 41 of Set 13 | abha
# Processing Record 42 of Set 13 | athgarh
# City not found. Skipping...
# Processing Record 43 of Set 13 | new port richey
# Processing Record 44 of Set 13 | manono
# Processing Record 45 of Set 13 | tottori
# Processing Record 46 of Set 13 | makung
# City not found. Skipping...
# Processing Record 47 of Set 13 | qandala
# Processing Record 48 of Set 13 | glendive
# Processing Record 49 of Set 13 | villazon
# Processing Record 50 of Set 13 | woodinville
# Processing Record 1 of Set 14 | goderich
# Processing Record 2 of Set 14 | praya
# Processing Record 3 of Set 14 | ilula
# Processing Record 4 of Set 14 | bonfim
# Processing Record 5 of Set 14 | caravelas
# Processing Record 6 of Set 14 | tres arroyos
# Processing Record 7 of Set 14 | sorland
# Processing Record 8 of Set 14 | north bend
# Processing Record 9 of Set 14 | kostino
# Processing Record 10 of Set 14 | casablanca
# Processing Record 11 of Set 14 | kincardine
# Processing Record 12 of Set 14 | sheltozero
# Processing Record 13 of Set 14 | braniewo
# Processing Record 14 of Set 14 | necochea
# Processing Record 15 of Set 14 | xinyu
# Processing Record 16 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 14 | asau
# Processing Record 18 of Set 14 | hyeres
# Processing Record 19 of Set 14 | hukuntsi
# Processing Record 20 of Set 14 | burica
# City not found. Skipping...
# Processing Record 21 of Set 14 | sakakah
# Processing Record 22 of Set 14 | pundaguitan
# Processing Record 23 of Set 14 | beisfjord
# Processing Record 24 of Set 14 | general pico
# Processing Record 25 of Set 14 | korhogo
# Processing Record 26 of Set 14 | yashkul
# Processing Record 27 of Set 14 | karasburg
# Processing Record 28 of Set 14 | monroe
# Processing Record 29 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 14 | madimba
# Processing Record 32 of Set 14 | quatre cocos
# Processing Record 33 of Set 14 | bozoum
# Processing Record 34 of Set 14 | lugovoy
# Processing Record 35 of Set 14 | sindor
# Processing Record 36 of Set 14 | terney
# Processing Record 37 of Set 14 | aksum
# Processing Record 38 of Set 14 | bonavista
# Processing Record 39 of Set 14 | nouadhibou
# Processing Record 40 of Set 14 | cabo san lucas
# Processing Record 41 of Set 14 | elko
# Processing Record 42 of Set 14 | wewak
# Processing Record 43 of Set 14 | nampula
# Processing Record 44 of Set 14 | coyoles central
# Processing Record 45 of Set 14 | dongsheng
# Processing Record 46 of Set 14 | fasa
# Processing Record 47 of Set 14 | akom
# Processing Record 48 of Set 14 | evanston
# Processing Record 49 of Set 14 | knysna
# Processing Record 50 of Set 14 | lake city
# Processing Record 1 of Set 15 | vaitape
# Processing Record 2 of Set 15 | bossangoa
# Processing Record 3 of Set 15 | telfs
# Processing Record 4 of Set 15 | asola
# Processing Record 5 of Set 15 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 15 | mianyang
# Processing Record 7 of Set 15 | tuy hoa
# Processing Record 8 of Set 15 | ambilobe
# Processing Record 9 of Set 15 | mariel
# Processing Record 10 of Set 15 | alnashi
# Processing Record 11 of Set 15 | kudahuvadhoo
# Processing Record 12 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 13 of Set 15 | carutapera
# Processing Record 14 of Set 15 | tiznit
# Processing Record 15 of Set 15 | portage
# Processing Record 16 of Set 15 | sao luiz gonzaga
# Processing Record 17 of Set 15 | esmeraldas
# Processing Record 18 of Set 15 | mitu
# Processing Record 19 of Set 15 | mazatlan
# Processing Record 20 of Set 15 | banepa
# Processing Record 21 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 15 | manadhoo
# Processing Record 23 of Set 15 | glotovka
# Processing Record 24 of Set 15 | linjiang
# Processing Record 25 of Set 15 | hovd
# Processing Record 26 of Set 15 | gorin
# Processing Record 27 of Set 15 | diffa
# Processing Record 28 of Set 15 | grand gaube
# Processing Record 29 of Set 15 | binabalian
# Processing Record 30 of Set 15 | yeppoon
# Processing Record 31 of Set 15 | temirtau
# Processing Record 32 of Set 15 | sohbatpur
# Processing Record 33 of Set 15 | muroto
# Processing Record 34 of Set 15 | nuevo progreso
# Processing Record 35 of Set 15 | kibre mengist
# Processing Record 36 of Set 15 | catazaja
# Processing Record 37 of Set 15 | boa vista
# Processing Record 38 of Set 15 | rocha
# Processing Record 39 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 15 | wufeng
# Processing Record 41 of Set 15 | harper
# Processing Record 42 of Set 15 | port-de-paix
# City not found. Skipping...
# Processing Record 43 of Set 15 | samfya
# Processing Record 44 of Set 15 | whitehorse
# Processing Record 45 of Set 15 | talara
# Processing Record 46 of Set 15 | villa union
# Processing Record 47 of Set 15 | isernia
# Processing Record 48 of Set 15 | arona
# Processing Record 49 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 15 | male
# Processing Record 1 of Set 16 | lakhdenpokhya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Katsuura  35.1333  140.3000     75.24        92         100       14.27
# 1      Rikitea -23.1203 -134.9692     74.71        78          59       13.94
# 2      Ushuaia -54.8000  -68.3000     29.86        74          75       18.41
# 3        Tavda  58.0425   65.2726     65.35        86          20        4.52
# 4    Carnarvon -24.8667  113.6333     66.27       100          75        0.00
# 5    Kathmandu  27.7167   85.3167     70.02        94          75        2.30
# 6     Barcelos  41.5388   -8.6151     81.68        56           0        1.95
# 7   Safranbolu  41.2508   32.6942     64.83        97          85        2.08
# 8  Devils Lake  48.1128  -98.8651     84.31        58           0       18.41
# 9   Georgetown   5.4112  100.3354     84.13        92          20        3.44
#
#   Country Current Description
# 0      JP           light rain
# 1      PF           light rain
# 2      AR           light snow
# 3      RU           few clouds
# 4      AU        broken clouds
# 5      NP        broken clouds
# 6      PT            clear sky
# 7      TR           light rain
# 8      US            clear sky
# 9      MY        moderate rain

# %%
new_column_order = ["City", "Country","Lat","Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description "]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Katsuura      JP  35.1333  140.3000     75.24        92         100
# 1    Rikitea      PF -23.1203 -134.9692     74.71        78          59
# 2    Ushuaia      AR -54.8000  -68.3000     29.86        74          75
# 3      Tavda      RU  58.0425   65.2726     65.35        86          20
# 4  Carnarvon      AU -24.8667  113.6333     66.27       100          75
#
#    Wind Speed Current Description
# 0       14.27           light rain
# 1       13.94           light rain
# 2       18.41           light snow
# 3        4.52           few clouds
# 4        0.00        broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
